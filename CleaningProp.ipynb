# %% [markdown]
# <a href="https://colab.research.google.com/github/fathimayusuff/Code/blob/main/CleaningProp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df =pd.read_csv('predicates9.csv')
df1 =pd.read_csv('predicates10.csv')

# %%
df.count()
# Out:
# pred    52744
# key     52744
# dtype: int64

# %%
df1.count()
# Out:
# pred    1437
# key     1437
# dtype: int64

# %%
match = df1[df1['pred'].str.match('http://dbpedia.org/ontology/')]

# %%
type(match)
# Out:
# pandas.core.frame.DataFrame

# %%
match.head()
# Out:
#                                         pred  key
# 1       http://dbpedia.org/ontology/spokenIn    1
# 15  http://dbpedia.org/ontology/militaryUnit   15
# 16      http://dbpedia.org/ontology/district   16
# 17     http://dbpedia.org/ontology/coachClub   17
# 18  http://dbpedia.org/ontology/militaryRank   18

# %%
match.count()
# Out:
# pred    1394
# key     1394
# dtype: int64

# %%
predicates9=pd.DataFrame
predicates10=pd.DataFrame

# %%
predicates9 = df.pred.str.split('http://dbpedia.org/property/', n = 1, expand = True)
predicates10= match.pred.str.split("http://dbpedia.org/ontology/", n = 1, expand = True)

# %%
predicates9 = df.pred.str.split('http://dbpedia.org/property/', n = 1, expand = True)
predicates10= match.pred.str.split("http://dbpedia.org/ontology/", n = 1, expand = True)

# %%
list1=[]
lis2=[]

# %%
list1 = list(predicates9[1].values)

# %%
list1.index('domain(s)_')
# Out:
# 23393

# %%
list2=list(predicates10[1].values)

# %%
low9 = set()
low10=set()

# %%
low9=set(predicates9[1].str.lower())
low10=set(predicates10[1].str.lower())

# %%
list_clean=[]

# %%
low10=Cleaner(list(low10))

# %%
low9=Cleaner(list(low9))

# %%
def Cleaner(lister):
  list_clean=[]
  for sent in lister:
              cleaned_sentence=removal_of_links(sent)
              cleaned_sentence=remove_emojis(cleaned_sentence)
              cleaned_sentence=remove_html_tags(cleaned_sentence)
              cleaned_sentence=remove_punctuation_marks(cleaned_sentence)
              list_clean.append(cleaned_sentence)
  return list_clean

# %%
low10
# Out:
# ['tennissurfacetype',
#  'cmykcoordinatecyanic',
#  'album',
#  'configuration',
#  'headlabel',
#  'area',
#  'riverbranch',
#  'champion',
#  'date',
#  'firstgame',
#  'coachingrecord',
#  'numberoffilms',
#  'releaselocation',
#  'maximumtemperature',
#  'constituencydistrict',
#  'electionmajority',
#  'mirdockings',
#  'sire',
#  'membership',
#  'foundedby',
#  'alternativename',
#  'numberofstudents',
#  'championindoublemale',
#  'meanoftransportationweight',
#  'governorgeneral',
#  'ispartofwineregion',
#  'religioushead',
#  'populatedplaceareametro',
#  'distancetodouglas',
#  'numberofpiersinwater',
#  'launchvehicle',
#  'firstpublicationdate',
#  'settingofplay',
#  'drugscom',
#  'genereviewsname',
#  'coverartist',
#  'loadlimit',
#  'bridgecarries',
#  'programminglanguage',
#  'introduced',
#  'code',
#  'railwaylineusingtunnel',
#  'formerchoreographer',
#  'countyseat',
#  'regionallanguage',
#  'planetperiapsis',
#  'language',
#  'governor',
#  'vein',
# ...

# %%
len(low10)
# Out:
# 1394

# %%
len(low9)
# Out:
# 51320

# %%
low9=set(low9)

# %%
low10=set(low10)

# %%
dup=low9.intersection(low10)
len(dup)
# Out:
# 850

# %%
list(dup)

# %%
predicates10.head()
# Out:
#    0             1
# 1         spokenIn
# 15    militaryUnit
# 16        district
# 17       coachClub
# 18    militaryRank

# %%
diff1 = set()
dif2=set()

# %%
diff1 = low9-set(low10)

# %%
diff2 = set(low10)-low9

# %%
len(diff1) #587
# Out:
# 50012

# %%
len(diff2)
# Out:
# 544

# %%
low9
# Out:
# ['replacedby',
#  'commonnames',
#  'musiceditor',
#  'careerrecord',
#  'hw',
#  'rltotalpoints',
#  'wsemis',
#  'domains',
#  'enginetotal',
#  'h9number',
#  'telescopearea',
#  'firstshow',
#  'worldchampsfirst',
#  'singleslink',
#  'stateleagueresult',
#  'w3seed',
#  'float8caption',
#  'animal1type',
#  'debutantes',
#  'thirdreviewersrating',
#  'designatedother1name',
#  'enginehp',
#  'week721color',
#  'motoamericapodiums',
#  'maximumtemperature',
#  'locationmapsize',
#  'birth1930date',
#  'valvelead',
#  'row214color',
#  'nyroutes',
#  'lineup',
#  'presidentcandidatesother',
#  'lon5min',
#  'espngrades',
#  'bronzeuru',
#  'season8playoffloss',
#  'testcaptain',
#  'cameraname',
#  'envelopes',
#  '1namedata',
#  'previrlpos',
#  'wb',
#  'stageevent4men',
#  'otname',
#  'recruit',
#  'kickboxloss',
#  'runtupdate',
#  'season4playoffloss',
#  'spacesvertical',
#  'list1l',
#  'country1capital',
#  'famouspersonality',
#  'coorpinpoint',
#  'session8start',
# ...

# %%
len(low9)
# Out:
# 50862

# %%
predicates9[1]=Cleaner(predicates9[1])

# %%
df[9453:9455]['pred']
# 2930,',
#  '9434,',
#  '9454,',
#  '9487,',
#  '16943,',
#  '16954,',
#  '18015,',
#  '22726,',
#  '22752,',
#  '22771,',
#  '23455,',
#  '24529,',
#  '36592,',
#  '36614,',
#  '37955,',
#  '40083,',
#  '40316,',
#  '40329,',
#  '40333,',
# Out:
# 9453      http://dbpedia.org/property/gym
# 9454    http://dbpedia.org/property/число
# Name: pred, dtype: object

# %%
predicates10[1]=Cleaner(predicates10[1])

# %%
import re

# name = 'CamelCaseName'
# # name = re.sub(r'(?<!^)(?=[A-Z])', ' ', name).lower()
# print(name)

def camelCaseConverter(name):
  return re.sub(r'(?<!^)(?=[A-Z])', ' ', name).lower()

# %%
type(camelCaseConverter("helloWorld"))
# Out:
# str

# %%
  val =predicates9.loc[predicates9[1].str.fullmatch('oficialname', case =False)]
  res = val[0].to_string()
  res=res.replace("\n", ",").strip()
  key = val[1].to_string().replace("    ", ",").strip()
  pred = camelCaseConverter(key)
  # if val[1].count()>2:
  #   list(pred)
  # if(type(pred))
  # if(key=='Series([], )'):
  #   print(val)

# %%
key
# Out:
# '41398,oficialName'

# %%
if val[1].count()>1:
  print("here")
  for index, value in val[1].items():
    pred1 = camelCaseConverter(value)
    pred=str(index)+','+pred1
    kDict.append(pred)

else:
  print(val[1])
# Out:
# 41398    oficialName
# Name: 1, dtype: object

# %%
kDict
# Out:
# ['12350,domains',
#  '23393,domains',
#  '2206,all lyrics',
#  '35193,alllyrics',
#  '12350,domains',
#  '23393,domains',
#  '2206,all lyrics',
#  '35193,alllyrics']

# %%
type(val[1])
# Out:
# pandas.core.series.Series

# %%
kDict=[]

# %%
kDict.append(val[1])

# %%
kDict
# Out:
# [12350    domains
#  23393    domains
#  Name: 1, dtype: object, 12350    domains
#  23393    domains
#  Name: 1, dtype: object]

# %%
# predicates10[1] = predicates10[1].str.lower()

# %%
i=0

# %%
kList=[]
kDup=[]
failedL=[]
keyF=[]

# %%
l2=list(diff1)

# %%
l2

# %%
i=0

# %%
diff1

# %%
for l in diff1:
  i+=1
  try:
    val =predicates9.loc[predicates9[1].str.fullmatch(l, case =False)]
    key = val[1].to_string().replace("    ", ",").strip()
    if key=='Series([], )':
        keyF.append(l)
    else:
      if val[1].count()>1:
        for index, value in val[1].items():
          # pred1 = camelCaseConverter(key)
          # pred1 = camelCaseConverter(value)
          pred=str(index)+','+value
          # pred=str(index)+','+value
          kDup.append(pred)
      else:
          # key = val[1].to_string().replace("    ", ",").strip()
          # pred = camelCaseConverter(key)
        kList.append(key)
    print(i)
  except:
    failedL.append(l)
    continue
# Out:
# Streaming output truncated to the last 5000 lines.
# 45013
# 45014
# 45015
# 45016
# 45017
# 45018
# 45019
# 45020
# 45021
# 45022
# 45023
# 45024
# 45025
# 45026
# 45027
# 45028
# 45029
# 45030
# 45031
# 45032
# 45033
# 45034
# 45035
# 45036
# 45037
# 45038
# 45039
# 45040
# 45041
# 45042
# 45043
# 45044
# 45045
# 45046
# 45047
# 45048
# 45049
# 45050
# 45051
# 45052
# 45053
# 45054
# 45055
# 45056
# 45057
# 45058
# 45059
# 45060
# 45061
# 45062
# 45063
# 45064
# 45065
# 45066
# 45067
# 45068
# 45069
# 45070
# 45071
# 45072
# 45073
# 45074
# 45075
# 45076
# 45077
# 45078
# 45079
# 45080
# 45081
# 45082
# 45083
# 45084
# 45085
# 45086
# 45087
# 45088
# 45089
# 45090
# 45091
# 45092
# 45093
# 45094
# 45095
# 45096
# 45097
# 45098
# 45099
# 45100
# 45101
# 45102
# 45103
# 45104
# 45105
# 45106
# 45107
# 45108
# 45109
# 45110
# 45111
# 45112
# 45113
# 45114
# 45115
# 45116
# 45117
# 45118
# 45119
# 45120
# 45121
# 45122
# 45123
# 45124
# 45125
# 45126
# 45127
# 45128
# 45129
# 45130
# ...

# %%
len(kList)
# Out:
# 48457

# %%
kList
# Out:
# ['39200,european overall championships best',
#  '50637,is this simply a repeat of a point made by the previous se...',
#  'series([], )']

# %%
kDup
# Out:
# ['2779,replacedBy',
#  '19147,replacedby',
#  '2930,',
#  '9434,',
#  '9454,',
#  '9487,',
#  '16943,',
#  '16954,',
#  '18015,',
#  '22726,',
#  '22752,',
#  '22771,',
#  '23455,',
#  '24529,',
#  '36592,',
#  '36614,',
#  '37955,',
#  '40083,',
#  '40316,',
#  '40329,',
#  '40333,',
#  '40344,',
#  '40351,',
#  '40352,',
#  '41961,',
#  '42488,',
#  '43387,',
#  '43406,',
#  '45233,',
#  '45249,',
#  '49101,',
#  '49173,',
#  '51068,',
#  '39014,firstShow',
#  '39178,firstshow',
#  '14233,session8Start',
#  '47245,session8start',
#  '8386,minister2pfo',
#  '12680,minister2Pfo',
#  '13647,englishMotto',
#  '21827,englishmotto',
#  '131,headCoach',
#  '254,headcoach',
#  '51223,headCoach',
#  '4753,barWidth',
#  '6224,barwidth',
#  '6149,posttitle',
#  '43930,postTitle',
#  '5820,confChampResult',
#  '15524,confchampresult',
#  '195,confRecord',
#  '262,confrecord',
#  '23402,pinCode',
#  '25566,pincode',
#  '36497,pincode',
#  '12377,backgroundColour',
#  '14157,backgroundcolour',
# ...

# %%
len(kDup)
# Out:
# 3235

# %%
len(failedL)
# Out:
# 0

# %%
len(keyF)
# Out:
# 0

# %%
dfCh = pd.DataFrame(kList, index=None, columns=None)

# %%
dfCh.to_csv('property_Fin.csv', index=False, header=False)

# %%
dfK = pd.DataFrame(kDup, index=None, columns=None)

# %%
dfK.to_csv('property_dup.csv', index=False, header=False)

# %%
keyF
# Out:
# ['domain(s)_',
#  'landarea(sq.mi)_',
#  'voicetype(s)_',
#  'name(s)_',
#  'reign*%23_',
#  '%22cis2%5ctimes2/3%7bb8(agis)%7dcis(e)cis4%5ctimes2/3%7bc8(da)%7d%5ctimes2/3%7bb(cis%3fgis)%7d%5ctimes2/3%7ba%5cdim(bis%5c!dis%3f%7d%5ctimes2/3%7beisfisa)%7dgis4(fis)%7d%3c/score%3e;excerpt11(violin)%3cscorevorbis',
#  'literacyrate(avg.%25)_',
#  'internationalcup(s)afccup(playoffstage)_',
#  'engine(prop)_',
#  'bestscorer(a)_',
#  'cost(adult)_',
#  'vitc(inmg)_',
#  '@%22(%3f%3cnumint%3e%5cd+)%5cw+%22_',
#  "ship's(fake)capacity",
#  'yearsactive(singing)_',
# ...

# %%
dfList = pd.DataFrame(kList, index=None, columns=None)

# %%
dfList.head()
# Out:
#                                      0
# 0  2779, replaced by\n19147,replacedby
# 1                   17691,common names
# 2                   29499,music editor
# 3                   2802,career record
# 4                                79,hw

# %%
dfList.to_csv('property1.csv', index=False, header=False)

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
list1= string.punctuation

# %%
list1.replace('_',"")
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^`{|}~'

# %%
        def remove_punctuation_marks(document):
            punctuation_free_text="".join([word for word in document if word not in list1])
            return punctuation_free_text

        def remove_html_tags(document):
            initialize_soup=BeautifulSoup(document,'lxml')
            tags_free_context=initialize_soup.get_text()
            return tags_free_context

        # def removal_of_stopwords(document):
        #     document_text = [word for word in document if word !='text']  #removing string text
        #     context=[word for word in document_text if word not in stop_words]
        #     return context

        def removal_of_links(document):
            text = re.sub(r"http\S+", "", document, flags=re.MULTILINE)
            return text

        def remove_emojis(document):
            return document.encode('ascii', 'ignore').decode('ascii')

# %%
import bs4
from bs4 import BeautifulSoup
import string
